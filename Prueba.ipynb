# %%
def rectangulo_izq(f, a, b, n):
    h = (b - a) / n
    x = a + h * np.arange(0, n)          
    return h * np.sum(f(x))

def rectangulo_der(f, a, b, n):
    h = (b - a) / n
    x = a + h * np.arange(1, n + 1)      
    return h * np.sum(f(x))

def punto_medio(f, a, b, n):
    h = (b - a) / n
    x = a + h * (np.arange(0, n) + 0.5)  
    return h * np.sum(f(x))

def trapecio(f, a, b, n):
    h = (b - a) / n
    x = a + h * np.arange(0, n + 1)      #
    y = f(x)
    return h * (0.5 * y[0] + np.sum(y[1:-1]) + 0.5 * y[-1])
# Out:
# Error in parse(text = input): <text>:2:5: unexpected symbol
# 1:
# 2: def rectangulo_izq
#        ^
# Traceback:
